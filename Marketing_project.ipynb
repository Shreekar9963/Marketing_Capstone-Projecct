# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("/content/data.xlsx")

# %%
data.head()
# Out:
#    Restaurant ID              Restaurant Name  Country Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
data.isnull().sum(0)
# Out:
# Restaurant ID           0
# Restaurant Name         1
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data.shape[0]
# Out:
# 9551

# %%
data.isnull().sum(0)/data.shape[0]
# Out:
# Restaurant ID           0.000000
# Restaurant Name         0.000105
# Country Code            0.000000
# City                    0.000000
# Address                 0.000000
# Locality                0.000000
# Locality Verbose        0.000000
# Longitude               0.000000
# Latitude                0.000000
# Cuisines                0.000942
# Average Cost for two    0.000000
# Currency                0.000000
# Has Table booking       0.000000
# Has Online delivery     0.000000
# Price range             0.000000
# Aggregate rating        0.000000
# Rating color            0.000000
# Rating text             0.000000
# Votes                   0.000000
# dtype: float64

# %%
round(data.isnull().sum(0)/data.shape[0]*100,2)
# Out:
# Restaurant ID           0.00
# Restaurant Name         0.01
# Country Code            0.00
# City                    0.00
# Address                 0.00
# Locality                0.00
# Locality Verbose        0.00
# Longitude               0.00
# Latitude                0.00
# Cuisines                0.09
# Average Cost for two    0.00
# Currency                0.00
# Has Table booking       0.00
# Has Online delivery     0.00
# Price range             0.00
# Aggregate rating        0.00
# Rating color            0.00
# Rating text             0.00
# Votes                   0.00
# dtype: float64

# %%
data
# Out:
#       Restaurant ID                Restaurant Name  Country Code      City  \
# 0           7402935                           Skye            94   Jakarta
# 1           7410290       Satoo - Hotel Shangri-La            94   Jakarta
# 2           7420899                     Sushi Masa            94   Jakarta
# 3           7421967                 3 Wise Monkeys            94   Jakarta
# 4           7422489    Avec Moi Restaurant and Bar            94   Jakarta
# ...             ...                            ...           ...       ...
# 9546       18279289           BMG - All Day Dining             1  Dehradun
# 9547        2300497  Atmosphere Grill Cafe Sheesha             1    Kanpur
# 9548       18312106                     UrbanCrave             1    Kanpur
# 9549        3900245             Deena Chat Bhandar             1  Varanasi
# 9550       18246202                VNS Live Studio             1  Varanasi
#
#                                                 Address  \
# ...

# %%
data[data['Restaurant Name'].isnull()]
# Out:
#       Restaurant ID Restaurant Name  Country Code       City  \
# 1646         113702             NaN             1  Ahmedabad
#
#                                           Address  Locality  \
# 1646  Opposite Sindhu Bhawan, Bodakdev, Ahmedabad  Bodakdev
#
#          Locality Verbose  Longitude   Latitude  \
# 1646  Bodakdev, Ahmedabad  72.501764  23.040163
#
#                                          Cuisines  Average Cost for two  \
# 1646  North Indian, Continental, Mexican, Italian                   800
#
#                 Currency Has Table booking Has Online delivery  Price range  \
# 1646  Indian Rupees(Rs.)                No                  No            3
#
#       Aggregate rating Rating color Rating text  Votes
# 1646               4.1        Green   Very Good    769

# %%
data.head()
# Out:
#    Restaurant ID              Restaurant Name  Country Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
cc=pd.read_excel("/content/Country-Code.xlsx")

# %%
data_rest=pd.merge(data,cc,how='left',on='Country Code' )

# %%
data_rest.columns = data_rest.columns.str.replace(' ','_')

# %%
data_rest
# Out:
#       Restaurant_ID                Restaurant_Name  Country_Code      City  \
# 0           7402935                           Skye            94   Jakarta
# 1           7410290       Satoo - Hotel Shangri-La            94   Jakarta
# 2           7420899                     Sushi Masa            94   Jakarta
# 3           7421967                 3 Wise Monkeys            94   Jakarta
# 4           7422489    Avec Moi Restaurant and Bar            94   Jakarta
# ...             ...                            ...           ...       ...
# 9546       18279289           BMG - All Day Dining             1  Dehradun
# 9547        2300497  Atmosphere Grill Cafe Sheesha             1    Kanpur
# 9548       18312106                     UrbanCrave             1    Kanpur
# 9549        3900245             Deena Chat Bhandar             1  Varanasi
# 9550       18246202                VNS Live Studio             1  Varanasi
#
#                                                 Address  \
# ...

# %%
data_rest.columns
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Price_range', 'Aggregate_rating',
#        'Rating_color', 'Rating_text', 'Votes', 'Country'],
#       dtype='object')

# %%
data_rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         9551 non-null   int64
#  1   Restaurant_Name       9550 non-null   object
#  2   Country_Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality_Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average_Cost_for_two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has_Table_booking     9551 non-null   object
#  13  Has_Online_delivery   9551 non-null   object
#  14  Price_range           9551 non-null   int64
# ...

# %%
data_rest.isnull
# Out:
# <bound method DataFrame.isnull of       Restaurant_ID                Restaurant_Name  Country_Code      City  \
# 0           7402935                           Skye            94   Jakarta
# 1           7410290       Satoo - Hotel Shangri-La            94   Jakarta
# 2           7420899                     Sushi Masa            94   Jakarta
# 3           7421967                 3 Wise Monkeys            94   Jakarta
# 4           7422489    Avec Moi Restaurant and Bar            94   Jakarta
# ...             ...                            ...           ...       ...
# 9546       18279289           BMG - All Day Dining             1  Dehradun
# 9547        2300497  Atmosphere Grill Cafe Sheesha             1    Kanpur
# 9548       18312106                     UrbanCrave             1    Kanpur
# 9549        3900245             Deena Chat Bhandar             1  Varanasi
# 9550       18246202                VNS Live Studio             1  Varanasi
#
# ...

# %%
data_rest.isnull().sum(0)
# Out:
# Restaurant_ID           0
# Restaurant_Name         1
# Country_Code            0
# City                    0
# Address                 0
# Locality                0
# Locality_Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average_Cost_for_two    0
# Currency                0
# Has_Table_booking       0
# Has_Online_delivery     0
# Price_range             0
# Aggregate_rating        0
# Rating_color            0
# Rating_text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
data_rest[data_rest['Restaurant_Name'].isnull()]
# Out:
#       Restaurant_ID Restaurant_Name  Country_Code       City  \
# 1646         113702             NaN             1  Ahmedabad
#
#                                           Address  Locality  \
# 1646  Opposite Sindhu Bhawan, Bodakdev, Ahmedabad  Bodakdev
#
#          Locality_Verbose  Longitude   Latitude  \
# 1646  Bodakdev, Ahmedabad  72.501764  23.040163
#
#                                          Cuisines  Average_Cost_for_two  \
# 1646  North Indian, Continental, Mexican, Italian                   800
#
#                 Currency Has_Table_booking Has_Online_delivery  Price_range  \
# 1646  Indian Rupees(Rs.)                No                  No            3
#
#       Aggregate_rating Rating_color Rating_text  Votes Country
# 1646               4.1        Green   Very Good    769   India

# %%
data_rest.dropna(axis=0,subset=['Restaurant_Name'],inplace=True)

# %%
data_rest.reset_index(drop=True,inplace=True)

# %%
data_rest[data_rest['Cuisines'].isnull()]
# Out:
#       Restaurant_ID                 Restaurant_Name  Country_Code  \
# 9082       17374552                  Corkscrew Cafe           216
# 9085       17501439                        Dovetail           216
# 9093       17059060                       Hillstone           216
# 9405       17284158               Jimmie's Hot Dogs           216
# 9493       17142698                Leonard's Bakery           216
# 9503       17616465        Tybee Island Social Club           216
# 9532       17284105                   Cookie Shoppe           216
# 9534       17284211  Pearly's Famous Country Cookng           216
# 9538       17606621            HI Lite Bar & Lounge           216
#
#                 City                                          Address  \
# 9082     Gainesville                51 W Main St, Dahlonega, GA 30533
# 9085           Macon                   543 Cherry St, Macon, GA 31201
# 9093         Orlando  215 South Orlando Avenue, Winter Park, FL 32789
# ...

# %%
data_rest['Cuisines'].fillna(value='others',inplace=True)

# %%
data_rest.isnull().sum(0)
# Out:
# Restaurant_ID           0
# Restaurant_Name         0
# Country_Code            0
# City                    0
# Address                 0
# Locality                0
# Locality_Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average_Cost_for_two    0
# Currency                0
# Has_Table_booking       0
# Has_Online_delivery     0
# Price_range             0
# Aggregate_rating        0
# Rating_color            0
# Rating_text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
data_rest
# Out:
#       Restaurant_ID                Restaurant_Name  Country_Code      City  \
# 0           7402935                           Skye            94   Jakarta
# 1           7410290       Satoo - Hotel Shangri-La            94   Jakarta
# 2           7420899                     Sushi Masa            94   Jakarta
# 3           7421967                 3 Wise Monkeys            94   Jakarta
# 4           7422489    Avec Moi Restaurant and Bar            94   Jakarta
# ...             ...                            ...           ...       ...
# 9545       18279289           BMG - All Day Dining             1  Dehradun
# 9546        2300497  Atmosphere Grill Cafe Sheesha             1    Kanpur
# 9547       18312106                     UrbanCrave             1    Kanpur
# 9548        3900245             Deena Chat Bhandar             1  Varanasi
# 9549       18246202                VNS Live Studio             1  Varanasi
#
#                                                 Address  \
# ...

# %%
cntry_dist=data_rest.groupby(['Country_Code','Country']).agg(Count=('Restaurant_ID','count'))

# %%
cntry_dist.sort_values(by='Count',ascending=False)
# Out:
#                              Count
# Country_Code Country
# 1            India            8651
# 216          United States     434
# 215          United Kingdom     80
# 30           Brazil             60
# 189          South Africa       60
# 214          UAE                60
# 148          New Zealand        40
# 208          Turkey             34
# 14           Australia          24
# 162          Phillipines        22
# 94           Indonesia          21
# 166          Qatar              20
# 184          Singapore          20
# 191          Sri Lanka          20
# 37           Canada              4

# %%
city_dist=data_rest.groupby(['Country','City']).agg(Count=('Restaurant_ID','count'))

# %%
city_dist.describe()
# Out:
#              Count
# count   141.000000
# mean     67.730496
# std     476.723952
# min       1.000000
# 25%       1.000000
# 50%      20.000000
# 75%      20.000000
# max    5473.000000

# %%
city_dist.sort_values(by='Count',ascending=False)
# Out:
#                               Count
# Country       City
# India         New Delhi        5473
#               Gurgaon          1118
#               Noida            1080
#               Faridabad         251
#               Ghaziabad          25
# ...                             ...
#               Panchkula           1
# Australia     Balingup            1
# Indonesia     Bandung             1
# Phillipines   Quezon City         1
# United States Winchester Bay      1
#
# [141 rows x 1 columns]

# %%
min_cnt_rest=city_dist[city_dist['Count'] == 1 ]

# %%
min_cnt_rest
# Out:
#                                 Count
# Country       City
# Australia     Armidale              1
#               Balingup              1
#               Beechworth            1
#               Dicky Beach           1
#               East Ballina          1
#               Flaxton               1
#               Forrest               1
#               Huskisson             1
#               Inverloch             1
#               Lakes Entrance        1
#               Lorn                  1
#               Macedon               1
#               Mayfield              1
#               Middleton Beach       1
#               Montville             1
#               Palm Cove             1
#               Paynesville           1
#               Penola                1
#               Phillip Island        1
#               Tanunda               1
#               Trentham East         1
#               Victor Harbor         1
# Canada        Chatham-Kent          1
# ...

# %%
min_cnt_rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 46 entries, ('Australia', 'Armidale') to ('United States', 'Winchester Bay')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Count   46 non-null     int64
# dtypes: int64(1)
# memory usage: 1.8+ KB

# %%
max_rest_cnt=city_dist[city_dist['Count'] > 100]

# %%
max_rest_cnt
# Out:
#                    Count
# Country City
# India   Faridabad    251
#         Gurgaon     1118
#         New Delhi   5473
#         Noida       1080

# %%
franch_rest=data_rest.groupby(['Restaurant_Name','Country']).agg(Count=('Country','count'))

# %%
franch_rest.sort_values(by='Count',ascending=False)
# Out:
#                                               Count
# Restaurant_Name                 Country
# Cafe Coffee Day                 India            83
# Domino's Pizza                  India            79
# Subway                          India            63
# Green Chick Chop                India            51
# McDonald's                      India            48
# ...                                             ...
# Gibson's Gourmet Burgers & Ribs South Africa      1
# Giapo                           New Zealand       1
# Giani's di Hatti                India             1
# Gian Ji Punjabi Dhaba           India             1
# Ìàukura€Ùa Sofras€±             Turkey            1
#
# [7472 rows x 1 columns]

# %%
franch_rest.describe()
# Out:
#              Count
# count  7472.000000
# mean      1.278105
# std       2.165675
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max      83.000000

# %%
data_rest1=data_rest.copy()

# %%
data_rest1
# Out:
#       Restaurant_ID                Restaurant_Name  Country_Code      City  \
# 0           7402935                           Skye            94   Jakarta
# 1           7410290       Satoo - Hotel Shangri-La            94   Jakarta
# 2           7420899                     Sushi Masa            94   Jakarta
# 3           7421967                 3 Wise Monkeys            94   Jakarta
# 4           7422489    Avec Moi Restaurant and Bar            94   Jakarta
# ...             ...                            ...           ...       ...
# 9545       18279289           BMG - All Day Dining             1  Dehradun
# 9546        2300497  Atmosphere Grill Cafe Sheesha             1    Kanpur
# 9547       18312106                     UrbanCrave             1    Kanpur
# 9548        3900245             Deena Chat Bhandar             1  Varanasi
# 9549       18246202                VNS Live Studio             1  Varanasi
#
#                                                 Address  \
# ...

# %%
dummy=['Has_Table_booking','Has_Online_delivery']

# %%
data_rest1=pd.get_dummies(data_rest1,columns=dummy,drop_first=True)

# %%
data_rest1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
Table_booking=data_rest1[data_rest1['Has_Table_booking_Yes'] == True]['Restaurant_ID'].count()

# %%
Table_booking
# Out:
# 1158

# %%
Table_bookingN=data_rest1[data_rest1['Has_Table_booking_Yes'] == False]['Restaurant_ID'].count()

# %%
Table_bookingN
# Out:
# 8392

# %%
print('Ratio of restaurants which allow table booking by which dont allow table booking',round((Table_booking/Table_bookingN),2))
# Out:
# Ratio of restaurants which allow table booking by which dont allow table booking 0.14

# %%
print(Table_booking,Table_bookingN)
# Out:
# 1158 8392

# %%
Online_del=data_rest1[data_rest1['Has_Online_delivery_Yes'] == True]['Restaurant_ID'].count()

# %%
Online_delN=data_rest1[data_rest1['Has_Online_delivery_Yes'] == False]['Restaurant_ID'].count()

# %%
perc=round((Online_del/len(data_rest1)),3)

# %%
perc
# Out:
# 0.257

# %%
len(data_rest1)
# Out:
# 9550

# %%
Online_del
# Out:
# 2451

# %%
Online_delN
# Out:
# 7099

# %%
perc_Online_Del=(round(((Online_del)/len(data_rest1)),3)*100).astype(str) + '%'

# %%
perc_Online_Del
# Out:
# '25.7%'

# %%
rest_deliver=data_rest1[data_rest1['Has_Online_delivery_Yes'] == True]['Votes'].sum()

# %%
rest_deliverN=data_rest1[data_rest1['Has_Online_delivery_Yes'] == False]['Votes'].sum()

# %%
difference_delivery=abs((rest_deliver - rest_deliverN))

# %%
difference_delivery
# Out:
# 462048

# %%
data_rest1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
data_rest.to_csv('cleaned_data.csv')

# %%
top_cuisines1 = data_rest.groupby('City')['Cuisines'].apply(lambda x: x.value_counts().index[0]).to_frame().reset_index()
top_cuisines1.columns = ['City','Top Cuisine']

# %%
top_cuisines1
# Out:
#                 City                         Top Cuisine
# 0          Abu Dhabi                              Indian
# 1               Agra               North Indian, Mughlai
# 2          Ahmedabad  Continental, Chinese, North Indian
# 3             Albany                              others
# 4          Allahabad               North Indian, Chinese
# ..               ...                                 ...
# 136          Weirton             Burger, Greek, Sandwich
# 137  Wellington City                                Cafe
# 138   Winchester Bay              Burger, Seafood, Steak
# 139          Yorkton                               Asian
# 140        €¡stanbul                                Cafe
#
# [141 rows x 2 columns]

# %%
top_10_cuisines = top_cuisines1.groupby('Top Cuisine')['City'].count().sort_values(ascending = False).head(10)

# %%
top_10_cuisines
# Out:
# Top Cuisine
# Cafe                     10
# Mexican                   8
# North Indian, Chinese     7
# North Indian              7
# Italian                   4
# Indian                    3
# Filipino                  3
# American                  2
# Brazilian                 2
# Seafood                   2
# Name: City, dtype: int64

# %%
Max_cuisine_count=data_rest.groupby('Restaurant_Name')['Cuisines'].nunique().max()

# %%
Min_cuisine_count=data_rest.groupby('Restaurant_Name')['Cuisines'].nunique().min()

# %%
Min_cuisine_count
# Out:
# 1

# %%
most_served_cuisine = data_rest.groupby('City')['Cuisines'].apply(lambda x : x.value_counts().index[0]).to_frame().reset_index()

# %%
most_served_cuisine
# Out:
#                 City                            Cuisines
# 0          Abu Dhabi                              Indian
# 1               Agra               North Indian, Mughlai
# 2          Ahmedabad  Continental, Chinese, North Indian
# 3             Albany                              others
# 4          Allahabad               North Indian, Chinese
# ..               ...                                 ...
# 136          Weirton             Burger, Greek, Sandwich
# 137  Wellington City                                Cafe
# 138   Winchester Bay              Burger, Seafood, Steak
# 139          Yorkton                               Asian
# 140        €¡stanbul                                Cafe
#
# [141 rows x 2 columns]

# %%
from re import A
data_rest['average_cost']=(data_rest['Average_Cost_for_two']/2)

# %%
data_rest['average_cost']
# Out:
# 0       400000.0
# 1       400000.0
# 2       250000.0
# 3       225000.0
# 4       175000.0
#           ...
# 9545         0.0
# 9546         0.0
# 9547         0.0
# 9548         0.0
# 9549         0.0
# Name: average_cost, Length: 9550, dtype: float64

# %%
data_rest.to_csv('cap1.csv')

# %%
avg_cost_dist=data_rest.groupby(['Restaurant_Name','average_cost']).agg(Count=('Restaurant_ID','count'))
avg_cost_dist.sort_values(by='Count',ascending=False)
# Out:
#                                                             Count
# Restaurant_Name                               average_cost
# Cafe Coffee Day                               225.0            83
# Domino's Pizza                                350.0            79
# Subway                                        250.0            62
# Green Chick Chop                              175.0            51
# McDonald's                                    250.0            46
# ...                                                           ...
# Game of Legends - Sports Bar, Grill, & Lounge 725.0             1
# Game n Grillz                                 425.0             1
# Gallery CafÌ© - Hyatt Place                   750.0             1
# Galleria de Paco                              20.0              1
# Ìàukura€Ùa Sofras€±                           30.0              1
#
# [7969 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
sns.pairplot(data_rest, y_vars=['Aggregate_rating'], x_vars=['Rating_text','Votes'])
plt.show()

# %%
data_rest.columns
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Price_range', 'Aggregate_rating',
#        'Rating_color', 'Rating_text', 'Votes', 'Country', 'average_cost'],
#       dtype='object')

# %%
data_cuisines=data_rest['Cuisines'].apply(lambda x : pd.Series(x.split(',')))

# %%
data_cuisines.columns=['Cuisine1','Cuisine2','Cuisine3','Cuisine4','Cuisine5','Cuisine6','Cuisine7','Cuisine8']

# %%
data_cuisines.head()
# Out:
#    Cuisine1      Cuisine2  Cuisine3 Cuisine4 Cuisine5 Cuisine6 Cuisine7  \
# 0   Italian   Continental       NaN      NaN      NaN      NaN      NaN
# 1     Asian    Indonesian   Western      NaN      NaN      NaN      NaN
# 2     Sushi      Japanese       NaN      NaN      NaN      NaN      NaN
# 3  Japanese           NaN       NaN      NaN      NaN      NaN      NaN
# 4    French       Western       NaN      NaN      NaN      NaN      NaN
#
#   Cuisine8
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df_cuisines=pd.concat([data_rest,data_cuisines],axis=1)

# %%
df_cuisines.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
cuisine_loc = pd.DataFrame(df_cuisines[['Country','City','Locality_Verbose','Cuisine1','Cuisine2','Cuisine3',
                                        'Cuisine4','Cuisine5','Cuisine6','Cuisine7','Cuisine8']])

# %%
cuisine_loc.head()
# Out:
#      Country     City                        Locality_Verbose  Cuisine1  \
# 0  Indonesia  Jakarta  Grand Indonesia Mall, Thamrin, Jakarta   Italian
# 1  Indonesia  Jakarta     Hotel Shangri-La, Sudirman, Jakarta     Asian
# 2  Indonesia  Jakarta                    Penjaringan, Jakarta     Sushi
# 3  Indonesia  Jakarta                       Senopati, Jakarta  Japanese
# 4  Indonesia  Jakarta                        Thamrin, Jakarta    French
#
#        Cuisine2  Cuisine3 Cuisine4 Cuisine5 Cuisine6 Cuisine7 Cuisine8
# 0   Continental       NaN      NaN      NaN      NaN      NaN      NaN
# 1    Indonesian   Western      NaN      NaN      NaN      NaN      NaN
# 2      Japanese       NaN      NaN      NaN      NaN      NaN      NaN
# 3           NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 4       Western       NaN      NaN      NaN      NaN      NaN      NaN

# %%
cuisine_loc_stack=pd.DataFrame(cuisine_loc.stack())

# %%
cuisine_loc_stack=pd.DataFrame(cuisine_loc.stack())

# %%
cuisine_loc_stack.head(10)
# Out:
#                                                          0
# 0 Country                                        Indonesia
#   City                                             Jakarta
#   Locality_Verbose  Grand Indonesia Mall, Thamrin, Jakarta
#   Cuisine1                                         Italian
#   Cuisine2                                     Continental
# 1 Country                                        Indonesia
#   City                                             Jakarta
#   Locality_Verbose     Hotel Shangri-La, Sudirman, Jakarta
#   Cuisine1                                           Asian
#   Cuisine2                                      Indonesian

# %%
keys = [c for c in cuisine_loc  if c.startswith('Cuisine')]
a=pd.melt(cuisine_loc, id_vars='Locality_Verbose', value_vars=keys, value_name='Cuisines')

# %%
a.head()
# Out:
#                          Locality_Verbose  variable  Cuisines
# 0  Grand Indonesia Mall, Thamrin, Jakarta  Cuisine1   Italian
# 1     Hotel Shangri-La, Sudirman, Jakarta  Cuisine1     Asian
# 2                    Penjaringan, Jakarta  Cuisine1     Sushi
# 3                       Senopati, Jakarta  Cuisine1  Japanese
# 4                        Thamrin, Jakarta  Cuisine1    French

# %%
rest_cuisine=pd.DataFrame(df_cuisines[['Restaurant_Name','City','Cuisine1','Cuisine2','Cuisine3','Cuisine4','Cuisine5','Cuisine6','Cuisine7','Cuisine8']])

# %%
rest_cuisine.head()
# Out:
#                Restaurant_Name     City  Cuisine1      Cuisine2  Cuisine3  \
# 0                         Skye  Jakarta   Italian   Continental       NaN
# 1     Satoo - Hotel Shangri-La  Jakarta     Asian    Indonesian   Western
# 2                   Sushi Masa  Jakarta     Sushi      Japanese       NaN
# 3               3 Wise Monkeys  Jakarta  Japanese           NaN       NaN
# 4  Avec Moi Restaurant and Bar  Jakarta    French       Western       NaN
#
#   Cuisine4 Cuisine5 Cuisine6 Cuisine7 Cuisine8
# 0      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN

# %%
rest_cuisine.stack=pd.DataFrame(rest_cuisine.stack())

# %%
rest_cuisine.stack.head()
# Out:
#                                           0
# 0 Restaurant_Name                      Skye
#   City                              Jakarta
#   Cuisine1                          Italian
#   Cuisine2                      Continental
# 1 Restaurant_Name  Satoo - Hotel Shangri-La

# %%
keys=[c for c in rest_cuisine if c.startswith('Cuisine')]
b=pd.melt(rest_cuisine,id_vars='Restaurant_Name',value_vars=keys,value_name='Cuisines')

# %%
b.head()
# Out:
#                Restaurant_Name  variable  Cuisines
# 0                         Skye  Cuisine1   Italian
# 1     Satoo - Hotel Shangri-La  Cuisine1     Asian
# 2                   Sushi Masa  Cuisine1     Sushi
# 3               3 Wise Monkeys  Cuisine1  Japanese
# 4  Avec Moi Restaurant and Bar  Cuisine1    French

# %%
max_rate1=pd.DataFrame(b.groupby(by=['Restaurant_Name','variable','Cuisines']).size().reset_index())

# %%
max_rate1
# Out:
#             Restaurant_Name  variable       Cuisines  0
# 0                     12212  Cuisine1      Fast Food  1
# 1              Let's Burrrp  Cuisine1        Chinese  1
# 2              Let's Burrrp  Cuisine2   North Indian  1
# 3                       #45  Cuisine1           Cafe  1
# 4              #Dilliwaala6  Cuisine1   North Indian  1
# ...                     ...       ...            ... ..
# 15959  {Niche} - Cafe & Bar  Cuisine2        Chinese  1
# 15960  {Niche} - Cafe & Bar  Cuisine3        Italian  1
# 15961  {Niche} - Cafe & Bar  Cuisine4    Continental  1
# 15962   Ìàukura€Ùa Sofras€±  Cuisine1          Kebab  1
# 15963   Ìàukura€Ùa Sofras€±  Cuisine2         Izgara  1
#
# [15964 rows x 4 columns]

# %%
del max_rate1['variable']

# %%
max_rate1.columns=['Restaurant_Name','Cuisines','Count']

# %%
max_rate1
# Out:
#             Restaurant_Name       Cuisines  Count
# 0                     12212      Fast Food      1
# 1              Let's Burrrp        Chinese      1
# 2              Let's Burrrp   North Indian      1
# 3                       #45           Cafe      1
# 4              #Dilliwaala6   North Indian      1
# ...                     ...            ...    ...
# 15959  {Niche} - Cafe & Bar        Chinese      1
# 15960  {Niche} - Cafe & Bar        Italian      1
# 15961  {Niche} - Cafe & Bar    Continental      1
# 15962   Ìàukura€Ùa Sofras€±          Kebab      1
# 15963   Ìàukura€Ùa Sofras€±         Izgara      1
#
# [15964 rows x 3 columns]

# %%
max_rate1.sort_values(by='Count',ascending=False)
# Out:
#               Restaurant_Name       Cuisines  Count
# 2479          Cafe Coffee Day           Cafe     83
# 4596           Domino's Pizza          Pizza     79
# 4597           Domino's Pizza      Fast Food     78
# 12984                  Subway          Salad     63
# 12985                  Subway   Healthy Food     63
# ...                       ...            ...    ...
# 5568   Gabbar's Bar & Kitchen        Chinese      1
# 5569   Gabbar's Bar & Kitchen        Mexican      1
# 5570   Gabbar's Bar & Kitchen        Italian      1
# 5571             Gaga Manjero  World Cuisine      1
# 15963     Ìàukura€Ùa Sofras€±         Izgara      1
#
# [15964 rows x 3 columns]

# %%
rating = data_rest1[['Restaurant_ID','Restaurant_Name','Country','City','Aggregate_rating','Average_Cost_for_two','Votes','Price_range','Has_Table_booking_Yes','Has_Online_delivery_Yes']]

# %%
rating=rating.merge(max_rate1,left_on='Restaurant_Name',right_on='Restaurant_Name',how='left')

# %%
rating
# Out:
#        Restaurant_ID           Restaurant_Name    Country      City  \
# 0            7402935                      Skye  Indonesia   Jakarta
# 1            7402935                      Skye  Indonesia   Jakarta
# 2            7410290  Satoo - Hotel Shangri-La  Indonesia   Jakarta
# 3            7410290  Satoo - Hotel Shangri-La  Indonesia   Jakarta
# 4            7410290  Satoo - Hotel Shangri-La  Indonesia   Jakarta
# ...              ...                       ...        ...       ...
# 23810       18312106                UrbanCrave      India    Kanpur
# 23811       18312106                UrbanCrave      India    Kanpur
# 23812        3900245        Deena Chat Bhandar      India  Varanasi
# 23813       18246202           VNS Live Studio      India  Varanasi
# 23814       18246202           VNS Live Studio      India  Varanasi
#
#        Aggregate_rating  Average_Cost_for_two  Votes  Price_range  \
# 0                   4.1                800000   1498            3
# ...

# %%
sns.regplot(x='Count',y='Aggregate_rating',data=rating)
rating[['Count','Aggregate_rating']].corr()
# Out:
#                      Count  Aggregate_rating
# Count             1.000000         -0.001642
# Aggregate_rating -0.001642          1.000000

# %%
sns.regplot(y='Aggregate_rating',x='Average_Cost_for_two',data=rating)
rating[['Aggregate_rating','Average_Cost_for_two']].corr()
# Out:
#                       Aggregate_rating  Average_Cost_for_two
# Aggregate_rating               1.00000               0.05011
# Average_Cost_for_two           0.05011               1.00000

# %%
sns.regplot(x='Votes',y='Aggregate_rating',data=rating)
rating[['Votes','Aggregate_rating']].corr()
# Out:
#                      Votes  Aggregate_rating
# Votes             1.000000          0.318667
# Aggregate_rating  0.318667          1.000000

# %%
sns.regplot(x='Has_Table_booking_Yes',y='Aggregate_rating',data=rating)
rating[['Has_Table_booking_Yes','Aggregate_rating']].corr()
# Out:
#                        Has_Table_booking_Yes  Aggregate_rating
# Has_Table_booking_Yes               1.000000          0.181843
# Aggregate_rating                    0.181843          1.000000

# %%
sns.regplot(x='Price_range',y='Aggregate_rating',data=rating)
rating[['Price_range','Aggregate_rating']].corr()
# Out:
#                   Price_range  Aggregate_rating
# Price_range          1.000000          0.462983
# Aggregate_rating     0.462983          1.000000

# %%
data_rest1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# ...

# %%
max_rate=data_rest1.sort_values(by='Aggregate_rating',ascending=False).groupby(['Country','City'],as_index=False).first()

# %%
min_rate=data_rest1.sort_values(by='Aggregate_rating',ascending=False).groupby(['Country','City'],as_index=False).last()

# %%
df_max=max_rate[['Country','City','Restaurant_Name','Aggregate_rating']]
df_min=min_rate[['Country','City','Restaurant_Name','Aggregate_rating']]

# %%
rating_res=df_max.merge(df_min,left_on='City',right_on='City',how='inner')

# %%
rating_res.head()
# Out:
#    Country_x          City    Restaurant_Name_x  Aggregate_rating_x  \
# 0  Australia      Armidale      Whitebull Hotel                 3.5
# 1  Australia      Balingup    Taste of Balingup                 3.2
# 2  Australia    Beechworth  Bridge Road Brewers                 4.6
# 3  Australia   Dicky Beach    The Giggling Goat                 3.6
# 4  Australia  East Ballina    The Belle General                 4.1
#
#    Country_y    Restaurant_Name_y  Aggregate_rating_y
# 0  Australia      Whitebull Hotel                 3.5
# 1  Australia    Taste of Balingup                 3.2
# 2  Australia  Bridge Road Brewers                 4.6
# 3  Australia    The Giggling Goat                 3.6
# 4  Australia    The Belle General                 4.1

# %%
rating_res.drop(columns='Country_y',axis=1,inplace=True)

# %%
rating_res.head()
# Out:
#    Country_x          City    Restaurant_Name_x  Aggregate_rating_x  \
# 0  Australia      Armidale      Whitebull Hotel                 3.5
# 1  Australia      Balingup    Taste of Balingup                 3.2
# 2  Australia    Beechworth  Bridge Road Brewers                 4.6
# 3  Australia   Dicky Beach    The Giggling Goat                 3.6
# 4  Australia  East Ballina    The Belle General                 4.1
#
#      Restaurant_Name_y  Aggregate_rating_y
# 0      Whitebull Hotel                 3.5
# 1    Taste of Balingup                 3.2
# 2  Bridge Road Brewers                 4.6
# 3    The Giggling Goat                 3.6
# 4    The Belle General                 4.1

# %%
rating_res.columns = ['Country','City','Highest Rated Restaurant','Rating Max','Lowest Rated Restaurant','Rating Min']
rating_res
# Out:
#            Country            City                  Highest Rated Restaurant  \
# 0        Australia        Armidale                           Whitebull Hotel
# 1        Australia        Balingup                         Taste of Balingup
# 2        Australia      Beechworth                       Bridge Road Brewers
# 3        Australia     Dicky Beach                         The Giggling Goat
# 4        Australia    East Ballina                         The Belle General
# ..             ...             ...                                       ...
# 136  United States        Valdosta                          Smok'n Pig B-B-Q
# 137  United States        Vernonia                           Blue House Cafe
# 138  United States        Waterloo                   Four Queens Dairy Cream
# 139  United States         Weirton  Theo Yianni's Authentic Greek Restaurant
# 140  United States  Winchester Bay                 Fishpatrick's Crabby Cafe
#
# ...
